# %%
from pyspark.sql.functions import *

# %%
daily = spark.table('workspace.idasky.daily_table')
hourly = spark.table('workspace.idasky.hourly_table')
location = spark.table('workspace.idasky.location')
display(daily)
display(hourly)
display(location)
